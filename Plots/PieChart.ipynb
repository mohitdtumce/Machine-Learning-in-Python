# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Let’s first define labels
projects = ['spychat', 'twitterAPI', 'instabot', 'Clarifai']

# Now Let’s see their contribution(the area which they’ll cover in Pie Chart)
area = [10, 7, 2, 13]

# Setting colors for each label
myColors = ['r', 'm', 'g', 'b']

# Plotting Pie Chart
plt.pie(area, labels = projects, colors = myColors, startangle = 90, shadow = True, explode = (0, 0, 0.1, 0), radius = 1.2, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a3d53fa5c0>,
#   <matplotlib.patches.Wedge at 0x1a3d5401eb8>,
#   <matplotlib.patches.Wedge at 0x1a3d54157b8>,
#   <matplotlib.patches.Wedge at 0x1a3d54250b8>],
#  [<matplotlib.text.Text at 0x1a3d5401400>,
#   <matplotlib.text.Text at 0x1a3d540bcc0>,
#   <matplotlib.text.Text at 0x1a3d541d5c0>,
#   <matplotlib.text.Text at 0x1a3d5425e80>],
#  [<matplotlib.text.Text at 0x1a3d5401978>,
#   <matplotlib.text.Text at 0x1a3d5415278>,
#   <matplotlib.text.Text at 0x1a3d541db38>,
#   <matplotlib.text.Text at 0x1a3d542f438>])

# %%
plt.legend()
plt.show()

# %%
plt.close()
